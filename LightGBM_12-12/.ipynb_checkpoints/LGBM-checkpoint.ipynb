# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#データの読み込み
df = pd.read_csv("CD3D_100-150℃_1.0-2.0ms_0.4-0.9V")

# %%
df1 = df.rename(columns={'V[V]': 'V','T_cell[℃]':'T','U_cath[m/s]':'U'})
df1
# Out:
#         Unnamed: 0       x座標       y座標       z座標     V      T    U  \
# 0                0  0.000800  0.010638  0.000617  0.45  100.0  1.0
# 1                1  0.000800  0.010638  0.000650  0.45  100.0  1.0
# 2                2  0.000738  0.010638  0.000650  0.45  100.0  1.0
# 3                3  0.000738  0.010441  0.000650  0.45  100.0  1.0
# 4                4  0.000800  0.010441  0.000650  0.45  100.0  1.0
# ...            ...       ...       ...       ...   ...    ...  ...
# 357781        1802  0.000185  0.000000  0.000550  0.90  150.0  2.0
# 357782        1803  0.000123  0.000000  0.000583  0.90  150.0  2.0
# 357783        1804  0.000000  0.000000  0.000550  0.90  150.0  2.0
# 357784        1805  0.000062  0.000000  0.000550  0.90  150.0  2.0
# 357785        1806  0.000123  0.000000  0.000550  0.90  150.0  2.0
#
#             i[A/m^2]
# 0       16377.285384
# 1       16338.307600
# 2       16364.027114
# 3       16370.911237
# 4       16346.807429
# ...              ...
# 357781   2184.167607
# 357782   2196.055654
# 357783   2206.078558
# 357784   2205.363425
# 357785   2200.222267
#
# [357786 rows x 8 columns]

# %%
#予測ターゲットの格納（住宅価格：A列）
target_df = df1[["i[A/m^2]"]]
#特徴量の格納（説明変数：B列以降）
train_df = df1.iloc[:,1:7]

#モデル学習のための、訓練データとテストデータを7:3で分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_df, target_df, test_size=0.3)

#XGBoostで学習するためのデータ形式に変換
dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_test, y_test)

#モデルパラメータの設定
params = {'metric' : 'rmse'}
model = lgb.train(params,dtrain)

#予測の実行と書き出し
pred = model.predict(X_test)
print(pred)

#散布図で予測の精度を描写
sns.set(font=['Meiryo','Yu Gothic'])
plt.scatter(y_test, pred, alpha = 0.5)
plt.plot(np.linspace(0, 35000), np.linspace(0, 35000), "red")
plt.xlabel('実際の電流密度')
plt.ylabel('予測値')
plt.show()

# 性能向上に寄与する度合いで重要度をプロット
lgb.plot_importance(model, height = 0.5, figsize = (8,16))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003549 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 106
# [LightGBM] [Info] Number of data points in the train set: 250450, number of used features: 6
# [LightGBM] [Info] Start training from score 10583.842905
# [16136.76754311  8895.79380697 24974.20289434 ...  6457.02229982
#  16678.95566491 13172.09003664]
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
df2 = df1[(df1["V"]==0.4) & (df1["T"]==100)&(df1["U"]==1.0)]

# %%
df3 = model.predict(df2.iloc[:,1:7])

# %%
fig1 = plt.figure(figsize=(12, 8))
ax1 = fig1.add_subplot(111, projection='3d')

sc1 = ax1.scatter(df2['x座標'], df2['y座標'],df2['z座標'], c=df3, cmap='jet', alpha=0.8)
plt.colorbar(sc1)

ax1.set_title("0.4V", fontsize=20)
ax1.set_xlabel('$x$', fontsize=15)
ax1.set_ylabel('$y$', fontsize=15)
ax1.set_zlabel('$z$', fontsize=15)
ax1.set_box_aspect((1,3,1))

ax1.set_xlim(-0.00055,0.001)
#ax1.set_ylim(0,0.015)
ax1.set_zlim(0,0.001)

#plt.savefig('PEM_CD_COMSOL.png')
plt.show()

# %%
df4 = df2.replace({'V': {0.4: 0.82}})
df5 = model.predict(df4.iloc[:,1:7])

# %%
fig2 = plt.figure(figsize=(12, 8))
ax2 = fig2.add_subplot(111, projection='3d')

sc2 = ax2.scatter(df4['x座標'], df4['y座標'],df4['z座標'], c=df5, cmap='jet', alpha=0.8)
plt.colorbar(sc1)

ax2.set_title("0.82V", fontsize=20)
ax2.set_xlabel('$x$', fontsize=15)
ax2.set_ylabel('$y$', fontsize=15)
ax2.set_zlabel('$z$', fontsize=15)
ax2.set_box_aspect((1,3,1))

ax2.set_xlim(-0.00055,0.001)
#ax2.set_ylim(0,0.015)
ax2.set_zlim(0,0.001)

#plt.savefig('PEM_CD_COMSOL.png')
plt.show()

# %%
I_ave = df3.mean()
I_ave
# Out:
# 19708.23057238959

# %%
def I_ave(V,T,U):
    global df1
    dfA = df1[(df1['V']==0.4) & (df1['T']==100)&(df1['U']==1.0)]
    dfB = dfA.replace({'V': {0.4: V}}).replace({'T': {100: T}}).replace({'U': {1.0: U}})
    dfC = model.predict(dfB.iloc[:,1:7])
    dfD = dfC.mean()
    print(dfD)

# %%
I_ave(0.4,100,1.0)
# Out:
# 19708.23057238959

# %%
dfA = df1[(df1['V']==0.4) & (df1['T']==100)&(df1['U']==1.0)]

# %%
df_li = []

for V in np.arange(0.4,0.9,0.01):
    for T in np.arange(100,150,1):
        for U in np.arange(1.0,2.0,0.10):
            df_li.append((V, T, U))
            
df_I = pd.DataFrame(df_li, columns=['V','T','U'])

# %%
df_I['i[A/m^2]'] = df_I[['V','T','U']].apply(I_ave2, axis=1)
print(df_I)
# Out:
#           V    T    U      i[A/m^2]
# 0      0.40  100  1.0  19702.150975
# 1      0.40  100  1.1  19702.150975
# 2      0.40  100  1.2  19702.150975
# 3      0.40  100  1.3  19972.673678
# 4      0.40  100  1.4  19972.673678
# ...     ...  ...  ...           ...
# 24995  0.89  149  1.5   2164.854453
# 24996  0.89  149  1.6   2164.854453
# 24997  0.89  149  1.7   2164.854453
# 24998  0.89  149  1.8   2171.184397
# 24999  0.89  149  1.9   2171.184397
#
# [25000 rows x 4 columns]

# %%
df_I['i[A/m^2]'].idxmax()
# Out:
# 468

# %%
df_I[468:469]
# Out:
#        V    T    U      i[A/m^2]
# 468  0.4  146  1.8  27490.646004

# %%
df_I2 = pd.DataFrame(df_I.round(2))

# %%
df_I3 = df_I2[(df_I2['V']== 0.50)&(df_I2['T']== 100)]
index = df_I3['i[A/m^2]'].idxmax()
index
df_I4 = df_I3.loc[[index]]
df_I4
# Out:
#         V    T    U  i[A/m^2]
# 5008  0.5  100  1.8  14193.49

# %%
df_Im = pd.DataFrame(columns=['V','T','U','i[A/m^2]'])
for V in np.arange(0.4,0.9,0.01):
    for T in np.arange(100,150,1):
        df_IVT = df_I2[(df_I2['V']== V.round(2))&(df_I2['T']== T)]
        maxindex = df_IVT['i[A/m^2]'].idxmax()
        #print(df_IVT.loc[[maxindex]])
        df_IVT2 = df_IVT.loc[[maxindex]]
        df_Im = df_Im.append(df_IVT2, ignore_index = True)

# %%
df_Im
# Out:
#          V    T    U  i[A/m^2]
# 0     0.40  100  1.8  20096.31
# 1     0.40  101  1.8  20096.31
# 2     0.40  102  1.8  20096.31
# 3     0.40  103  1.8  20096.31
# 4     0.40  104  1.8  20096.31
# ...    ...  ...  ...       ...
# 2495  0.89  145  1.8   1490.12
# 2496  0.89  146  1.8   2171.18
# 2497  0.89  147  1.8   2171.18
# 2498  0.89  148  1.8   2171.18
# 2499  0.89  149  1.8   2171.18
#
# [2500 rows x 4 columns]

# %%
fig3 = plt.figure(figsize=(12, 8))
ax3 = fig3.add_subplot(111, projection='3d')

sc3 = ax3.scatter(df_Im['V'], df_Im['T'],df_Im['U'], c=df_Im['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar(sc3)

ax3.set_title("0.4V", fontsize=20)
ax3.set_xlabel('$V$', fontsize=15)
ax3.set_ylabel('$T$', fontsize=15)
ax3.set_zlabel('$U$', fontsize=15)

#ax3.set_xlim(-0.0055,0.0055)
#ax3.set_ylim(0,0.015)
#ax3.set_zlim(-0.055,0.055)

#plt.savefig('PEM_CD_COMSOL.png')
plt.show()

# %%
fig4 = plt.figure(figsize=(12, 8))
ax4 = fig4.add_subplot(111, projection='3d')

sc4 = ax4.scatter(df_I['V'], df_I['T'],df_I['U'], c=df_I['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar(sc3)

ax4.set_title("0.4V", fontsize=20)
ax4.set_xlabel('$V$', fontsize=15)
ax4.set_ylabel('$T$', fontsize=15)
ax4.set_zlabel('$U$', fontsize=15)

#ax4.set_xlim(-0.0055,0.0055)
#ax4.set_ylim(0,0.015)
#ax4.set_zlim(-0.055,0.055)

#plt.savefig('PEM_CD_COMSOL.png')
plt.show()

# %%
from scipy.optimize import minimize #maximizeはないらしい。
from scipy.optimize import Bounds

# %%
def I_ave3(dfx):
    return -I_ave2(dfx)

# %%
#初期値
x0 = pd.DataFrame([[0.9,100,1.0]])
#制約条件
V_val = x[0]
T_val = x[1]
U_val = x[2]
dfx = pd.DataFrame([[V_val, T_val, U_val]])
bounds = Bounds([0.4,100,1.0],[0.9,150,2.0])
#最適化の実行
result = minimize(I_ave3,x0,bounds = bounds)
if result.success:
    optimal = result.dfx
    print("最適な条件:", optimal)
else:
    print("最適化に失敗しました。")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-60-9d08d8676edd> in <module>
#       8 bounds = Bounds([0.4,100,1.0],[0.9,150,2.0])
#       9 #最適化の実行
# ---> 10 result = minimize(I_ave3,x0,bounds = bounds)
#      11 if result.success:
#      12     optimal = result.dfx
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'l-bfgs-b':
#     617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#     620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     306     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                                   bounds=new_bounds,
# --> 308                                   finite_diff_rel_step=finite_diff_rel_step)
#     309
#     310     func_and_grad = sf.fun_and_grad
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     260     # calculation reduces overall function evaluations.
#     261     sf = ScalarFunction(fun, x0, args, grad, hess,
# --> 262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#     264     return sf
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#      74
#      75         self._update_fun_impl = update_fun
# ---> 76         self._update_fun()
#      77
#      78         # Gradient evaluation
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# <ipython-input-45-09b087d6e258> in I_ave3(dfx)
#       1 def I_ave3(dfx):
# ----> 2     return -I_ave2(dfx)
#
# <ipython-input-58-eeee3fb430a2> in I_ave2(dfx)
#       2     dfx  = pd.DataFrame([dfx])
#       3     global dfA
# ----> 4     dfB = dfA.replace({'V': {0.4: dfx.iloc[0]}}).replace({'T': {100: dfx.iloc[1]}}).replace({'U': {1.0: dfx.iloc[2]}})
#       5     dfC = model.predict(dfB.iloc[:,1:7])
#       6     dfD = dfC.mean()
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4387             limit=limit,
#    4388             regex=regex,
# -> 4389             method=method,
#    4390         )
#    4391
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6505
#    6506             return self.replace(
# -> 6507                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6508             )
#    6509         else:
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4387             limit=limit,
#    4388             regex=regex,
# -> 4389             method=method,
#    4390         )
#    4391
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6522                         if col in value.keys() and col in self
#    6523                     }
# -> 6524                     return self._replace_columnwise(mapping, inplace, regex)
#    6525
#    6526                 # {'A': NA} -> 0
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\frame.py in _replace_columnwise(self, mapping, inplace, regex)
#    4417
#    4418                 target, value = mapping[ax[i]]
# -> 4419                 newobj = ser.replace(target, value, regex=regex)
#    4420
#    4421                 res.iloc[:, i] = newobj
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4580             limit=limit,
#    4581             regex=regex,
# -> 4582             method=method,
#    4583         )
#    4584
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6551                         dest_list=value,
#    6552                         inplace=inplace,
# -> 6553                         regex=regex,
#    6554                     )
#    6555
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     669                         inplace=inplace,
#     670                         convert=convert,
# --> 671                         regex=regex,
#     672                     )
#     673                     if m.any() or convert:
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\internals\blocks.py in _replace_coerce(self, to_replace, value, inplace, regex, convert, mask)
#    1505             if not regex:
#    1506                 self = self.coerce_to_target_dtype(value)
# -> 1507                 return self.putmask(mask, value, inplace=inplace)
#    1508             else:
#    1509                 return self._replace_single(
#
# ~\anaconda3\envs\Tensorflow\lib\site-packages\pandas\core\internals\blocks.py in putmask(self, mask, new, inplace, axis, transpose)
#     920         """
#     921         mask = _extract_bool_array(mask)
# --> 922         assert not isinstance(new, (ABCIndexClass, ABCSeries, ABCDataFrame))
#     923
#     924         new_values = self.values  # delay copy if possible.
#
# AssertionError:

# %%
x0 = pd.DataFrame([[0.9,100,1.0]])
x0
# Out:
#      0    1    2
# 0  0.9  100  1.0

# %%
V_val
# Out:
# array([0.4 , 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.5 ,
#        0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61,
#        0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71, 0.72,
#        0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82, 0.83,
#        0.84, 0.85, 0.86, 0.87, 0.88, 0.89])

# %%
ex = np.array([0.4,100,1.0])
df_ex = pd.DataFrame([ex])
df_ex
# Out:
#      0      1    2
# 0  0.4  100.0  1.0

# %%
from gurobipy import *

# %%
dfA
# Out:
#       Unnamed: 0       x座標       y座標       z座標    V      T    U      i[A/m^2]
# 1807           0  0.000800  0.010638  0.000617  0.4  100.0  1.0  18879.111427
# 1808           1  0.000800  0.010638  0.000650  0.4  100.0  1.0  18816.761923
# 1809           2  0.000738  0.010638  0.000650  0.4  100.0  1.0  18886.012355
# 1810           3  0.000738  0.010441  0.000650  0.4  100.0  1.0  18886.457822
# 1811           4  0.000800  0.010441  0.000650  0.4  100.0  1.0  18820.111178
# ...          ...       ...       ...       ...  ...    ...  ...           ...
# 3609        1802  0.000185  0.000000  0.000550  0.4  100.0  1.0  20674.958022
# 3610        1803  0.000123  0.000000  0.000583  0.4  100.0  1.0  20857.986445
# 3611        1804  0.000000  0.000000  0.000550  0.4  100.0  1.0  20967.285415
# 3612        1805  0.000062  0.000000  0.000550  0.4  100.0  1.0  20958.042714
# 3613        1806  0.000123  0.000000  0.000550  0.4  100.0  1.0  20889.009217
#
# [1807 rows x 8 columns]

# %%
def I_ave2(dfx):
    #dfx  = pd.DataFrame(dfx, columns=['V', 'T', 'U'])
    global dfA
    dfA['V'] = dfx['V']
    dfA['T'] = dfx['T']
    dfA['U'] = dfx['U']
    dfC = model.predict(dfA.iloc[:,1:7])
    dfD = dfC.mean()
    return dfD

# %%
# 最適化問題の定義
modelG = gurobipy.Model("ML_Optimization")

# 変数の追加
V = modelG.addVar(vtype=GRB.CONTINUOUS, name="V",lb=0.4, ub=0.9)
T = modelG.addVar(vtype=GRB.CONTINUOUS, name="T", lb=100, ub=150)
U = modelG.addVar(vtype=GRB.CONTINUOUS, name="U", lb=1.0, ub=2.0)

# 目的関数の追加（機械学習の予測結果を組み込む）
modelG.setObjective(I_ave2(pd.DataFrame([[V, T, U]], columns=['V', 'T', 'U'])), sense=GRB.MAXIMIZE)

# 初期値の設定
V_start_value = 0.7
T_start_value = 125
U_start_value = 1.5
V.setAttr("Start", V_start_value)
T.setAttr("Start", T_start_value)
U.setAttr("Start", U_start_value)

# 最適化の実行
modelG.optimize()

# 結果の表示
print("Optimal value:", modelG.objVal)
print("V =", V.x)
print("T =", T.x)
print("U =", U.x)
# Out:
# C:\Users\aruhy\AppData\Local\Temp\ipykernel_11748\71088005.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA['V'] = dfx['V']
# C:\Users\aruhy\AppData\Local\Temp\ipykernel_11748\71088005.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA['T'] = dfx['T']
# C:\Users\aruhy\AppData\Local\Temp\ipykernel_11748\71088005.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA['U'] = dfx['U']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 10
#       7 U = modelG.addVar(vtype=GRB.CONTINUOUS, name="U", lb=1.0, ub=2.0)
#       9 # 目的関数の追加（機械学習の予測結果を組み込む）
# ---> 10 modelG.setObjective(I_ave2(pd.DataFrame([[V, T, U]], columns=['V', 'T', 'U'])), sense=GRB.MAXIMIZE)
#      12 # 初期値の設定
#      13 V_start_value = 0.7
#
# Cell In[30], line 7, in I_ave2(dfx)
#       5 dfA['T'] = dfx['T']
#       6 dfA['U'] = dfx['U']
# ----> 7 dfC = model.predict(dfA.iloc[:,1:7])
#       8 dfD = dfC.mean()
#       9 return dfD
#
# File ~\anaconda3\envs\MLMO\lib\site-packages\lightgbm\basic.py:4220, in Booster.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4218     else:
#    4219         num_iteration = -1
# -> 4220 return predictor.predict(
#    4221     data=data,
#    4222     start_iteration=start_iteration,
#    4223     num_iteration=num_iteration,
#    4224     raw_score=raw_score,
#    4225     pred_leaf=pred_leaf,
#    4226     pred_contrib=pred_contrib,
#    4227     data_has_header=data_has_header,
#    4228     validate_features=validate_features
#    4229 )
#
# File ~\anaconda3\envs\MLMO\lib\site-packages\lightgbm\basic.py:1004, in _InnerPredictor.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features)
#     995     _safe_call(
#     996         _LIB.LGBM_BoosterValidateFeatureNames(
#     997             self._handle,
#    (...)
#    1000         )
#    1001     )
#    1003 if isinstance(data, pd_DataFrame):
# -> 1004     data = _data_from_pandas(
#    1005         data=data,
#    1006         feature_name="auto",
#    1007         categorical_feature="auto",
#    1008         pandas_categorical=self.pandas_categorical
#    1009     )[0]
#    1011 predict_type = _C_API_PREDICT_NORMAL
#    1012 if raw_score:
#
# File ~\anaconda3\envs\MLMO\lib\site-packages\lightgbm\basic.py:703, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     700     categorical_feature = list(categorical_feature)  # type: ignore[assignment]
#     702 # get numpy representation of the data
# --> 703 _check_for_bad_pandas_dtypes(data.dtypes)
#     704 df_dtypes = [dtype.type for dtype in data.dtypes]
#     705 df_dtypes.append(np.float32)  # so that the target dtype considers floats
#
# File ~\anaconda3\envs\MLMO\lib\site-packages\lightgbm\basic.py:666, in _check_for_bad_pandas_dtypes(pandas_dtypes_series)
#     660 bad_pandas_dtypes = [
#     661     f'{column_name}: {pandas_dtype}'
#     662     for column_name, pandas_dtype in pandas_dtypes_series.items()
#     663     if not _is_allowed_numpy_dtype(pandas_dtype.type)
#     664 ]
#     665 if bad_pandas_dtypes:
# --> 666     raise ValueError('pandas dtypes must be int, float or bool.\n'
#     667                      f'Fields with bad pandas dtypes: {", ".join(bad_pandas_dtypes)}')
#
# ValueError: pandas dtypes must be int, float or bool.
# Fields with bad pandas dtypes: V: object, T: object, U: object
