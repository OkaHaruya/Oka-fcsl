# %%
import numpy as np
from tensorflow.keras.models import load_model
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


model = load_model('i_predict')

# %%
sc = StandardScaler()

# %%
df_aa = pd.read_csv('current density2 0.4-0.9V_std', usecols=[1,2,3,4])

# %%
df_a = df_aa.head(2451)
df_a
# Out:
#            x座標       y座標      V[V]  i[A/m^2]
# 0     1.680659  1.662026 -1.677952  0.138094
# 1     1.691588  1.600252 -1.677952  0.138094
# 2     1.706301  1.539141 -1.677952  0.138094
# 3     1.728089  1.432824 -1.677952  0.138094
# 4     1.733078  1.416454 -1.677952  0.138094
# ...        ...       ...       ...       ...
# 2446 -1.673740 -1.450546 -1.677952  3.223217
# 2447 -1.633360 -1.514238 -1.677952  3.223217
# 2448 -1.586292 -1.577929 -1.677952  3.223217
# 2449 -1.529742 -1.641621 -1.677952  3.223217
# 2450 -1.524813 -1.705312 -1.677952  3.223217
#
# [2451 rows x 4 columns]

# %%
df_ab = pd.read_csv('current density2 0.4-0.9V', usecols=[1,2,3,4])
df_c  = df_ab.head(2451)
df_c
# Out:
#            x座標       y座標  V[V]      i[A/m^2]
# 0     0.000669  0.010415   0.4  13057.283873
# 1     0.000671  0.010224   0.4  13057.283873
# 2     0.000673  0.010035   0.4  13057.283873
# 3     0.000677  0.009706   0.4  13057.283873
# 4     0.000678  0.009656   0.4  13057.283873
# ...        ...       ...   ...           ...
# 2446  0.000100  0.000788   0.4  32691.611952
# 2447  0.000107  0.000591   0.4  32691.611952
# 2448  0.000115  0.000394   0.4  32691.611952
# 2449  0.000125  0.000197   0.4  32691.611952
# 2450  0.000126  0.000000   0.4  32691.611952
#
# [2451 rows x 4 columns]

# %%
plt.figure(figsize=(12, 8)) #正規化されてるグラフ

plt.scatter(df_a['x座標'], df_a['y座標'], c=df_a['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar()

plt.title("test", fontsize=20)
plt.xlabel('$x$', fontsize=15)
plt.ylabel('$y$', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(12, 8)) #正規化されてないグラフ

plt.scatter(df_c['x座標'], df_c['y座標'], c=df_c['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar()

plt.title("test", fontsize=20)
plt.xlabel('$x$', fontsize=15)
plt.ylabel('$y$', fontsize=15)

plt.xlim(-0.0055,0.0055)

plt.show()

# %%
df_v = df_aa.loc[:,'V[V]']
v_mean = df_v.mean()
v_std = df_v.std()
print(v_mean)
print(v_std)
# Out:
# 0.0
# 1.0000158051540617

# %%
#predictで正規化された出力求める→全てのパラメータを正規化から戻す

# %%
#v_a =   np.array(v)*v_std + v_mean

# %%
#v_a

# %%
df_pre = pd.read_csv('current density2 0.4-0.9V', usecols=[1,2,3])

# %%
df_i_pre = pd.DataFrame(model.predict(df_pre), columns = ['i[A/m^2]'])

# %%
df_i_pre
# Out:
#        i[A/m^2]
# 0      0.424541
# 1      0.424143
# 2      0.423059
# 3      0.421694
# 4      0.421201
# ...         ...
# 31631 -0.918761
# 31632 -0.915673
# 31633 -0.912487
# 31634 -0.909096
# 31635 -0.907009
#
# [31636 rows x 1 columns]

# %%
df = pd.concat([df_pre, df_i_pre], axis=1)

# %%
df_b = df.head(2451)
df_b
# Out:
#            x座標       y座標      V[V]  i[A/m^2]
# 0     1.680659  1.662026 -1.677952  0.424541
# 1     1.691588  1.600252 -1.677952  0.424143
# 2     1.706301  1.539141 -1.677952  0.423059
# 3     1.728089  1.432824 -1.677952  0.421694
# 4     1.733078  1.416454 -1.677952  0.421201
# ...        ...       ...       ...       ...
# 2446 -1.673740 -1.450546 -1.677952  1.115941
# 2447 -1.633360 -1.514238 -1.677952  1.114528
# 2448 -1.586292 -1.577929 -1.677952  1.111691
# 2449 -1.529742 -1.641621 -1.677952  1.107002
# 2450 -1.524813 -1.705312 -1.677952  1.106926
#
# [2451 rows x 4 columns]

# %%
plt.figure(figsize=(12, 8))

plt.scatter(df_b['x座標'], df_b['y座標'], c=df_b['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar()

plt.title("test", fontsize=20)
plt.xlabel('$x$', fontsize=15)
plt.ylabel('$y$', fontsize=15)

plt.show()

# %%
df_i = pd.read_csv('current density2 0.4-0.9V', usecols=[4])

# %%
df_i.mean()
# Out:
# i[A/m^2]    12178.428176
# dtype: float64

# %%
df_i.std()
# Out:
# i[A/m^2]    6364.296429
# dtype: float64

# %%
df_i_re = df_i_pre*df_i.std() + df_i.mean()  #iの予測値の標準化を戻す
df_i_re
# Out:
#            i[A/m^2]
# 0      14880.334442
# 1      14877.797405
# 2      14870.899457
# 3      14862.213293
# 4      14859.074241
# ...             ...
# 31631   6331.163765
# 31632   6350.811006
# 31633   6371.089471
# 31634   6392.670216
# 31635   6405.955519
#
# [31636 rows x 1 columns]

# %%
df_i_re_c = df_i_re.head(2451)

# %%
plt.figure(figsize=(12, 8))

plt.scatter(df_c['x座標'], df_c['y座標'], c=df_i_re_c['i[A/m^2]'], cmap='jet', alpha=0.8)
plt.colorbar()

plt.title("test", fontsize=20)
plt.xlabel('$x$', fontsize=15)
plt.ylabel('$y$', fontsize=15)

plt.xlim(-0.0055,0.0055)

plt.show()
